# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import xport

# %%
df = pd.read_sas('Resources/P_SMQ.XPT', format='xport')

# %%
df
# Out:
#            SEQN  SMQ020  SMD030  SMQ040  SMQ050Q  SMQ050U  SMD057  SMQ078  \
# 0      109264.0     NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 1      109266.0     2.0     NaN     NaN      NaN      NaN     NaN     NaN
# 2      109267.0     2.0     NaN     NaN      NaN      NaN     NaN     NaN
# 3      109268.0     2.0     NaN     NaN      NaN      NaN     NaN     NaN
# 4      109271.0     1.0    18.0     1.0      NaN      NaN     NaN     2.0
# ...         ...     ...     ...     ...      ...      ...     ...     ...
# 11132  124815.0     1.0    27.0     3.0      2.0      4.0     2.0     NaN
# 11133  124817.0     2.0     NaN     NaN      NaN      NaN     NaN     NaN
# 11134  124818.0     2.0     NaN     NaN      NaN      NaN     NaN     NaN
# 11135  124821.0     2.0     NaN     NaN      NaN      NaN     NaN     NaN
# 11136  124822.0     2.0     NaN     NaN      NaN      NaN     NaN     NaN
#
#        SMD641  SMD650  SMD100FL  SMD100MN  SMQ670  SMQ621  SMD630  SMAQUEX2
# ...
